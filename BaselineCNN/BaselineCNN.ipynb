# %% [markdown]
# # Artificial Neural Networks and Deep Learning - Homework 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# - Team: Bio.log(y)
#
#
#
#
#
#
#
# - Members: Luca Lepore, Arianna Rigamonti, Michele Sala, Jacopo Libero Tettamanti
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## Baseline model on pre-processed data

# %% [markdown]
# ### ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np
import pandas as pd

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
import keras as tfk
from keras.layers import Input, Dense, Dropout, Lambda
from keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {tfk.__version__}")

# Import other libraries
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from PIL import Image
import matplotlib.gridspec as gridspec
import requests
from io import BytesIO
from sklearn.utils import resample, shuffle
from sklearn.utils.class_weight import compute_class_weight
from ipywidgets import interact, IntSlider, Dropdown
from tensorflow.keras.utils import to_categorical
import plotly.express as px
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# TensorFlow version: 2.16.1
# Keras version: 3.3.3

# %% [markdown]
# ## ⏳ Load Data

# %%
# Load dataset
train_augmented = np.load('/kaggle/input/images2/X_train_augmented_3x.npz')
X_train = train_augmented['images']
y_train = train_augmented['labels']

val_augmented = np.load('/kaggle/input/images2/X_val_augmented_3x.npz')
X_val = val_augmented['images']
y_val = val_augmented['labels']

test = np.load('/kaggle/input/images2/X_test.npz')
X_test = test['images']
y_test = test['labels']

test_augmented = np.load('/kaggle/input/images2/X_test_augmented_4x.npz')
X_test_augmented = test_augmented['images']
y_test_augmented = test_augmented['labels']

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Save unique labels
unique_labels = list(labels.values())
print(f'Unique labels: {unique_labels}')
# Out:
# Unique labels: ['Basophil', 'Eosinophil', 'Erythroblast', 'Immature granulocytes', 'Lymphocyte', 'Monocyte', 'Neutrophil', 'Platelet']

# %%
# Check the shape of the loaded images
print(f"Loaded X_train images shape: {X_train.shape}")
print(f"Loaded y_train labels shape: {y_train.shape}")
print(f"Min value X_train: {X_train.min()}, Max value X_train: {X_train.max()}\n")

print(f"Loaded X_val images shape: {X_val.shape}")
print(f"Loaded y_val labels shape: {y_val.shape}")
print(f"Min value X_val: {X_val.min()}, Max value X_val: {X_val.max()}\n")

print(f"Loaded X_test images shape: {X_test.shape}")
print(f"Loaded y_test labels shape: {y_test.shape}")
print(f"Min value X_test: {X_test.min()}, Max value X_test: {X_test.max()}\n")

print(f"Loaded X_test_augmented images shape: {X_test_augmented.shape}")
print(f"Loaded y_test_augmented labels shape: {y_test_augmented.shape}")
print(f"Min value X_test_augmented: {X_test_augmented.min()}, Max value X_test_augmented: {X_test_augmented.max()}")
# Out:
# Loaded X_train images shape: (21513, 96, 96, 3)
# Loaded y_train labels shape: (21513, 8)
# Min value X_train: 0.0, Max value X_train: 255.0
#
# Loaded X_val images shape: (7173, 96, 96, 3)
# Loaded y_val labels shape: (7173, 8)
# Min value X_val: 0.0, Max value X_val: 255.0
#
# Loaded X_test images shape: (2391, 96, 96, 3)
# Loaded y_test labels shape: (2391, 8)
# Min value X_test: 0, Max value X_test: 255
#
# Loaded X_test_augmented images shape: (9564, 96, 96, 3)
# Loaded y_test_augmented labels shape: (9564, 8)
# Min value X_test_augmented: 0.0, Max value X_test_augmented: 255.0

# %%
# Flatten the labels to class indices since they're in one-hot encoding
y_train_flat = np.argmax(y_train, axis=1)

# Calculate class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_flat),
    y=y_train_flat
)

# Convert the class weights to a dictionary
class_weight_dict = dict(enumerate(class_weights))

# Print the calculated class weights
print("Class weights:")
for class_index, weight in class_weight_dict.items():
    print(f"Class {class_index}: Weight {weight:.2f}")
# Out:
# Class weights:
# Class 0: Weight 1.75
# Class 1: Weight 0.69
# Class 2: Weight 1.38
# Class 3: Weight 0.74
# Class 4: Weight 1.76
# Class 5: Weight 1.50
# Class 6: Weight 0.64
# Class 7: Weight 0.91

# %% [markdown]
# ## 🧮 Define Network Parameters

# %%
# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8

# %%
# Number of training epochs
epochs = 200

# Batch size for training
batch_size = 64

# Learning rate
learning_rate = 0.001

# Print the defined parameters
print("Epochs:", epochs)
print("Batch Size:", batch_size)
# Out:
# Epochs: 200
# Batch Size: 64

# %% [markdown]
# ## 🛠️ Build the Model

# %%
# Define the CNN model
def build_model(
    input_shape=input_shape,
    output_shape=output_shape,
    learning_rate=learning_rate,
    seed=seed
):
    # Set the random seed for reproducibility
    tf.random.set_seed(seed)

    # Define the model architecture layer by layer
    inputs = tfkl.Input(shape=input_shape, name='Input')

    # First convolutional layer
    x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
    x = tfkl.Activation('relu', name='act1')(x)
    x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

    # Second convolutional layer
    x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
    x = tfkl.Activation('relu', name='act2')(x)
    x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

    # Flatten and dense output layer
    x = tfkl.Flatten(name='flatten')(x)
    x = tfkl.Dense(units=output_shape, name='dense')(x)
    outputs = tfkl.Activation('softmax', name='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=inputs, outputs=outputs, name='baseline_CNN')

    # Compile the model
    loss = tfk.losses.CategoricalCrossentropy()
    optimizer = tfk.optimizers.Adam(learning_rate)
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    return model

# %%
# Build the model with specified input and output shapes
model = build_model()

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "baseline_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ Input (InputLayer)          │ (None, 96, 96, 3)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv1 (Conv2D)              │ (None, 96, 96, 32)    │        896 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ act1 (Activation)           │ (None, 96, 96, 32)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ mp1 (MaxPooling2D)          │ (None, 48, 48, 32)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2 (Conv2D)              │ (None, 48, 48, 64)    │     18,496 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ act2 (Activation)           │ (None, 48, 48, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ mp2 (MaxPooling2D)          │ (None, 24, 24, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ flatten (Flatten)           │ (None, 36864)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 8)             │    294,920 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ softmax (Activation)        │ (None, 8)             │          0 │   -   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 314,312 (1.20 MB)
#  Trainable params: 314,312 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define the EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',       # Metric to monitor
    mode='max',                   # Mode ('max' for accuracy)
    patience=20,                  # Number of epochs with no improvement before stopping
    restore_best_weights=True     # Restore the model weights from the epoch with the best value of the monitored metric
)

# %%
# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',           # Metric to monitor
    factor=0.5,                   # Factor by which the learning rate will be reduced
    patience=5,                   # Number of epochs with no improvement before reducing learning rate
    verbose=1,                    # Verbosity mode (0 = silent, 1 = updates messages)
    min_lr=1e-6                   # Lower bound on the learning rate
)

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'baselineCNN_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732435329.684994      75 service.cc:145] XLA service 0x7e6b88005e20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732435329.685057      75 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#  20/337 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1351 - loss: 75.2381
# I0000 00:00:1732435332.229461      75 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.1840 - loss: 12.7859 - val_accuracy: 0.2148 - val_loss: 1.9927 - learning_rate: 0.0010
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2488 - loss: 1.8976 - val_accuracy: 0.2484 - val_loss: 2.0158 - learning_rate: 0.0010
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3305 - loss: 1.7368 - val_accuracy: 0.2709 - val_loss: 2.1201 - learning_rate: 0.0010
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3965 - loss: 1.5996 - val_accuracy: 0.2809 - val_loss: 2.3767 - learning_rate: 0.0010
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4471 - loss: 1.4822 - val_accuracy: 0.2870 - val_loss: 2.5050 - learning_rate: 0.0010
# Epoch 6/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4761 - loss: 1.4202
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4762 - loss: 1.4199 - val_accuracy: 0.2739 - val_loss: 2.5626 - learning_rate: 0.0010
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5280 - loss: 1.2872 - val_accuracy: 0.3239 - val_loss: 2.6650 - learning_rate: 5.0000e-04
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5885 - loss: 1.1290 - val_accuracy: 0.3310 - val_loss: 2.7995 - learning_rate: 5.0000e-04
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6353 - loss: 1.0157 - val_accuracy: 0.3389 - val_loss: 2.9845 - learning_rate: 5.0000e-04
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6695 - loss: 0.9295 - val_accuracy: 0.3421 - val_loss: 3.1864 - learning_rate: 5.0000e-04
# Epoch 11/200
# 332/337 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6880 - loss: 0.8716
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6882 - loss: 0.8710 - val_accuracy: 0.3311 - val_loss: 3.5444 - learning_rate: 5.0000e-04
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7113 - loss: 0.8178 - val_accuracy: 0.3462 - val_loss: 3.5603 - learning_rate: 2.5000e-04
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7414 - loss: 0.7328 - val_accuracy: 0.3434 - val_loss: 3.7823 - learning_rate: 2.5000e-04
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7711 - loss: 0.6567 - val_accuracy: 0.3446 - val_loss: 4.0990 - learning_rate: 2.5000e-04
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7969 - loss: 0.5948 - val_accuracy: 0.3443 - val_loss: 4.4901 - learning_rate: 2.5000e-04
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8158 - loss: 0.5402
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8158 - loss: 0.5401 - val_accuracy: 0.3342 - val_loss: 4.9200 - learning_rate: 2.5000e-04
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8215 - loss: 0.5166 - val_accuracy: 0.3499 - val_loss: 4.7721 - learning_rate: 1.2500e-04
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8388 - loss: 0.4751 - val_accuracy: 0.3488 - val_loss: 4.9520 - learning_rate: 1.2500e-04
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8571 - loss: 0.4305 - val_accuracy: 0.3508 - val_loss: 5.1153 - learning_rate: 1.2500e-04
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8731 - loss: 0.3899 - val_accuracy: 0.3496 - val_loss: 5.2978 - learning_rate: 1.2500e-04
# Epoch 21/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8900 - loss: 0.3543
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8901 - loss: 0.3542 - val_accuracy: 0.3496 - val_loss: 5.4909 - learning_rate: 1.2500e-04
# Epoch 22/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8895 - loss: 0.3441 - val_accuracy: 0.3529 - val_loss: 5.4810 - learning_rate: 6.2500e-05
# Epoch 23/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9013 - loss: 0.3149 - val_accuracy: 0.3576 - val_loss: 5.6124 - learning_rate: 6.2500e-05
# Epoch 24/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9117 - loss: 0.2879 - val_accuracy: 0.3556 - val_loss: 5.7455 - learning_rate: 6.2500e-05
# Epoch 25/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9205 - loss: 0.2652 - val_accuracy: 0.3562 - val_loss: 5.8521 - learning_rate: 6.2500e-05
# Epoch 26/200
# 333/337 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9268 - loss: 0.2453
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9268 - loss: 0.2453 - val_accuracy: 0.3584 - val_loss: 5.9863 - learning_rate: 6.2500e-05
# Epoch 27/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9303 - loss: 0.2358 - val_accuracy: 0.3593 - val_loss: 6.0341 - learning_rate: 3.1250e-05
# Epoch 28/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9337 - loss: 0.2263 - val_accuracy: 0.3622 - val_loss: 6.1127 - learning_rate: 3.1250e-05
# Epoch 29/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9391 - loss: 0.2151 - val_accuracy: 0.3618 - val_loss: 6.1875 - learning_rate: 3.1250e-05
# Epoch 30/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9421 - loss: 0.2055 - val_accuracy: 0.3622 - val_loss: 6.2674 - learning_rate: 3.1250e-05
# Epoch 31/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9462 - loss: 0.1959
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9462 - loss: 0.1959 - val_accuracy: 0.3636 - val_loss: 6.3393 - learning_rate: 3.1250e-05
# Epoch 32/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9465 - loss: 0.1922 - val_accuracy: 0.3665 - val_loss: 6.3937 - learning_rate: 1.5625e-05
# Epoch 33/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9471 - loss: 0.1882 - val_accuracy: 0.3665 - val_loss: 6.4314 - learning_rate: 1.5625e-05
# Epoch 34/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9494 - loss: 0.1827 - val_accuracy: 0.3668 - val_loss: 6.4709 - learning_rate: 1.5625e-05
# Epoch 35/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9510 - loss: 0.1779 - val_accuracy: 0.3675 - val_loss: 6.5145 - learning_rate: 1.5625e-05
# Epoch 36/200
# 334/337 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9525 - loss: 0.1734
# Epoch 36: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9525 - loss: 0.1734 - val_accuracy: 0.3676 - val_loss: 6.5572 - learning_rate: 1.5625e-05
# Epoch 37/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9533 - loss: 0.1722 - val_accuracy: 0.3696 - val_loss: 6.5921 - learning_rate: 7.8125e-06
# Epoch 38/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9542 - loss: 0.1690 - val_accuracy: 0.3694 - val_loss: 6.6304 - learning_rate: 7.8125e-06
# Epoch 39/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9548 - loss: 0.1659 - val_accuracy: 0.3689 - val_loss: 6.6577 - learning_rate: 7.8125e-06
# Epoch 40/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9558 - loss: 0.1634 - val_accuracy: 0.3682 - val_loss: 6.6820 - learning_rate: 7.8125e-06
# Epoch 41/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9564 - loss: 0.1609
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9563 - loss: 0.1609 - val_accuracy: 0.3694 - val_loss: 6.7018 - learning_rate: 7.8125e-06
# Epoch 42/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9567 - loss: 0.1604 - val_accuracy: 0.3699 - val_loss: 6.7526 - learning_rate: 3.9063e-06
# Epoch 43/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9567 - loss: 0.1584 - val_accuracy: 0.3689 - val_loss: 6.7680 - learning_rate: 3.9063e-06
# Epoch 44/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9570 - loss: 0.1570 - val_accuracy: 0.3686 - val_loss: 6.7818 - learning_rate: 3.9063e-06
# Epoch 45/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9573 - loss: 0.1556 - val_accuracy: 0.3689 - val_loss: 6.7947 - learning_rate: 3.9063e-06
# Epoch 46/200
# 331/337 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9578 - loss: 0.1544
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9578 - loss: 0.1543 - val_accuracy: 0.3687 - val_loss: 6.8093 - learning_rate: 3.9063e-06
# Epoch 47/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9575 - loss: 0.1538 - val_accuracy: 0.3689 - val_loss: 6.8267 - learning_rate: 1.9531e-06
# Epoch 48/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9579 - loss: 0.1528 - val_accuracy: 0.3687 - val_loss: 6.8350 - learning_rate: 1.9531e-06
# Epoch 49/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9581 - loss: 0.1520 - val_accuracy: 0.3690 - val_loss: 6.8429 - learning_rate: 1.9531e-06
# Epoch 50/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9589 - loss: 0.1513 - val_accuracy: 0.3694 - val_loss: 6.8509 - learning_rate: 1.9531e-06
# Epoch 51/200
# 331/337 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9591 - loss: 0.1507
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9590 - loss: 0.1506 - val_accuracy: 0.3696 - val_loss: 6.8575 - learning_rate: 1.9531e-06
# Epoch 52/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9587 - loss: 0.1503 - val_accuracy: 0.3701 - val_loss: 6.8623 - learning_rate: 1.0000e-06
# Epoch 53/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9594 - loss: 0.1497 - val_accuracy: 0.3704 - val_loss: 6.8650 - learning_rate: 1.0000e-06
# Epoch 54/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9594 - loss: 0.1494 - val_accuracy: 0.3697 - val_loss: 6.8693 - learning_rate: 1.0000e-06
# Epoch 55/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9596 - loss: 0.1489 - val_accuracy: 0.3699 - val_loss: 6.8732 - learning_rate: 1.0000e-06
# Epoch 56/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9597 - loss: 0.1486 - val_accuracy: 0.3701 - val_loss: 6.8770 - learning_rate: 1.0000e-06
# Epoch 57/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9597 - loss: 0.1482 - val_accuracy: 0.3703 - val_loss: 6.8809 - learning_rate: 1.0000e-06
# Epoch 58/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9598 - loss: 0.1479 - val_accuracy: 0.3700 - val_loss: 6.8845 - learning_rate: 1.0000e-06
# Epoch 59/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9599 - loss: 0.1476 - val_accuracy: 0.3706 - val_loss: 6.8880 - learning_rate: 1.0000e-06
# Epoch 60/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9601 - loss: 0.1473 - val_accuracy: 0.3706 - val_loss: 6.8914 - learning_rate: 1.0000e-06
# Epoch 61/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9601 - loss: 0.1469 - val_accuracy: 0.3707 - val_loss: 6.8935 - learning_rate: 1.0000e-06
# Epoch 62/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9600 - loss: 0.1467 - val_accuracy: 0.3703 - val_loss: 6.8978 - learning_rate: 1.0000e-06
# Epoch 63/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9601 - loss: 0.1463 - val_accuracy: 0.3701 - val_loss: 6.9020 - learning_rate: 1.0000e-06
# Epoch 64/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9600 - loss: 0.1460 - val_accuracy: 0.3699 - val_loss: 6.9060 - learning_rate: 1.0000e-06
# Epoch 65/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9602 - loss: 0.1457 - val_accuracy: 0.3700 - val_loss: 6.9097 - learning_rate: 1.0000e-06
# Epoch 66/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9601 - loss: 0.1454 - val_accuracy: 0.3701 - val_loss: 6.9117 - learning_rate: 1.0000e-06
# Epoch 67/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9605 - loss: 0.1452 - val_accuracy: 0.3701 - val_loss: 6.9162 - learning_rate: 1.0000e-06
# Epoch 68/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9608 - loss: 0.1448 - val_accuracy: 0.3700 - val_loss: 6.9202 - learning_rate: 1.0000e-06
# Epoch 69/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9609 - loss: 0.1445 - val_accuracy: 0.3699 - val_loss: 6.9240 - learning_rate: 1.0000e-06
# Epoch 70/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9609 - loss: 0.1442 - val_accuracy: 0.3704 - val_loss: 6.9262 - learning_rate: 1.0000e-06
# Epoch 71/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9613 - loss: 0.1439 - val_accuracy: 0.3701 - val_loss: 6.9309 - learning_rate: 1.0000e-06
# Epoch 72/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9613 - loss: 0.1436 - val_accuracy: 0.3701 - val_loss: 6.9348 - learning_rate: 1.0000e-06
# Epoch 73/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9612 - loss: 0.1433 - val_accuracy: 0.3697 - val_loss: 6.9387 - learning_rate: 1.0000e-06
# Epoch 74/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9612 - loss: 0.1429 - val_accuracy: 0.3700 - val_loss: 6.9410 - learning_rate: 1.0000e-06
# Epoch 75/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9616 - loss: 0.1427 - val_accuracy: 0.3701 - val_loss: 6.9458 - learning_rate: 1.0000e-06
# Epoch 76/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9616 - loss: 0.1424 - val_accuracy: 0.3701 - val_loss: 6.9496 - learning_rate: 1.0000e-06
# Epoch 77/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9618 - loss: 0.1420 - val_accuracy: 0.3700 - val_loss: 6.9518 - learning_rate: 1.0000e-06
# Epoch 78/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9620 - loss: 0.1418 - val_accuracy: 0.3699 - val_loss: 6.9562 - learning_rate: 1.0000e-06
# Epoch 79/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9620 - loss: 0.1414 - val_accuracy: 0.3699 - val_loss: 6.9604 - learning_rate: 1.0000e-06
# Epoch 80/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9621 - loss: 0.1411 - val_accuracy: 0.3696 - val_loss: 6.9625 - learning_rate: 1.0000e-06
# Epoch 81/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9621 - loss: 0.1409 - val_accuracy: 0.3703 - val_loss: 6.9672 - learning_rate: 1.0000e-06
# Final validation accuracy: 37.07%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# ## 🕹️ Use the Model - Make Inference

# %%
# Load the saved model
baseline = tfk.models.load_model('/kaggle/working/baselineCNN_37.07.keras')

# Display a summary of the model architecture
baseline.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(baseline, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "baseline_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ Input (InputLayer)          │ (None, 96, 96, 3)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv1 (Conv2D)              │ (None, 96, 96, 32)    │        896 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ act1 (Activation)           │ (None, 96, 96, 32)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ mp1 (MaxPooling2D)          │ (None, 48, 48, 32)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2 (Conv2D)              │ (None, 48, 48, 64)    │     18,496 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ act2 (Activation)           │ (None, 48, 48, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ mp2 (MaxPooling2D)          │ (None, 24, 24, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ flatten (Flatten)           │ (None, 36864)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 8)             │    294,920 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ softmax (Activation)        │ (None, 8)             │          0 │   -   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 942,938 (3.60 MB)
#  Trainable params: 314,312 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 628,626 (2.40 MB)

# %% [markdown]
# ### Test model on test set

# %% [markdown]
# #### 1. Test set without augmentation

# %%
# Predict labels for the entire test set
predictions = baseline.predict(X_test, verbose=0)

# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.5793
# Precision score over the test set: 0.5853
# Recall score over the test set: 0.5793
# F1 score over the test set: 0.5778

# %% [markdown]
# #### 2. Test set with augmentation

# %%
# Predict labels for the entire test set
predictions_aug = baseline.predict(X_test_augmented, verbose=0)

# Convert predictions to class labels
pred_classes_aug = np.argmax(predictions_aug, axis=-1)

# Extract ground truth classes
true_classes_aug = np.argmax(y_test_augmented, axis=-1)

# Calculate and display test set accuracy
accuracy_aug = accuracy_score(true_classes_aug, pred_classes_aug)
print(f'Accuracy score over the test set augmented: {round(accuracy_aug, 4)}')

# Calculate and display test set precision
precision_aug = precision_score(true_classes_aug, pred_classes_aug, average='weighted')
print(f'Precision score over the test set augmented: {round(precision_aug, 4)}')

# Calculate and display test set recall
recall_aug = recall_score(true_classes_aug, pred_classes_aug, average='weighted')
print(f'Recall score over the test set augmented: {round(recall_aug, 4)}')

# Calculate and display test set F1 score
f1_aug = f1_score(true_classes_aug, pred_classes_aug, average='weighted')
print(f'F1 score over the test set augmented: {round(f1_aug, 4)}')

# Compute the confusion matrix
cm_aug = confusion_matrix(true_classes_aug, pred_classes_aug)

# Combine numbers and percentages into a single string for annotation
annot_aug = np.array([f"{num}" for num in cm_aug.flatten()]).reshape(cm_aug.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm_aug.T, annot=annot_aug, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set augmented: 0.3089
# Precision score over the test set augmented: 0.2974
# Recall score over the test set augmented: 0.3089
# F1 score over the test set augmented: 0.3012

# %% [markdown]
# ## 📊 Prepare Your Submission
#
# To prepare your submission, create a `.zip` file that includes all the necessary code to run your model. It **must** include a `model.py` file with the following class:
#
# ```python
#
# # file: model.py
#
# import tensorflow as tf
# import numpy as np
#
# class Model:
#     def __init__(self):
#         """Initialize the internal state of the model."""
#
#         # Load the pre-trained model weights
#         self.model = tf.keras.models.load_model('weights.keras')  # Path to your saved weights
#
#     def predict(self, X):
#         """
#         Return a numpy array with the labels corresponding to the input X.
#         X: numpy array of input images.
#         """
#         predictions = self.model.predict(X)
#         # Return the class labels as a numpy array
#         return np.argmax(predictions, axis=-1)
#
# The next cell shows an example implementation of the `model.py` file, which includes loading model weights from the `weights.keras` file and conducting predictions on provided input data. The `.zip` file is created and downloaded in the last notebook cell.
#
# ❗ Feel free to modify the method implementations to better fit your specific requirements, but please ensure that the class name and method interfaces remain unchanged.

# %%
# %%writefile model.py

import numpy as np
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.
        """
        # Load the specific model file
        self.neural_network = tfk.models.load_model('baselineCNN_37.07.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must not be one-hot
        encoded.

        This function returns class labels as integers.
        """
        # Get predictions and convert to label format
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Writing model.py

# %%
from datetime import datetime

filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py baselineCNN_37.07.keras
# Out:
#   adding: model.py (deflated 52%)
#   adding: baselineCNN_37.07.keras (deflated 6%)
